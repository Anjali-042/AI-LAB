# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjali-042/AI-LAB/blob/main/042_8_queens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = 8


def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs


def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours


def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost


        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost


        if next_cost == current_cost:
            break
        else:
            current_state, current_cost = next_state, next_cost


        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost


initial_state = list(map(int, input("Enter initial state as 4 space-separated integers (0 to 7): ").split()))
solution_state, solution_cost = hillClimbing(initial_state)


print("\nFinal Results")
print("Initial State:", initial_state)
print("Final State (Solution):", solution_state)
print("Final Cost (Attacking Pairs):", solution_cost)

if solution_cost == 0:
    print("Solution found!")
else:
    print("Local optimum reached, but no solution.")
# Out:
# Enter initial state as 4 space-separated integers (0 to 7): 0 1 3 2 5 7 6 4
#
# Iteration 0
# Current State: [0, 1, 3, 2, 5, 7, 6, 4], Cost: 6
# Neighbour: [1, 0, 3, 2, 5, 7, 6, 4], Cost: 7
# Neighbour: [3, 1, 0, 2, 5, 7, 6, 4], Cost: 3
# Neighbour: [2, 1, 3, 0, 5, 7, 6, 4], Cost: 6
# Neighbour: [5, 1, 3, 2, 0, 7, 6, 4], Cost: 5
# Neighbour: [7, 1, 3, 2, 5, 0, 6, 4], Cost: 5
# Neighbour: [6, 1, 3, 2, 5, 7, 0, 4], Cost: 3
# Neighbour: [4, 1, 3, 2, 5, 7, 6, 0], Cost: 4
# Neighbour: [0, 3, 1, 2, 5, 7, 6, 4], Cost: 4
# Neighbour: [0, 2, 3, 1, 5, 7, 6, 4], Cost: 5
# Neighbour: [0, 5, 3, 2, 1, 7, 6, 4], Cost: 6
# Neighbour: [0, 7, 3, 2, 5, 1, 6, 4], Cost: 3
# Neighbour: [0, 6, 3, 2, 5, 7, 1, 4], Cost: 3
# Neighbour: [0, 4, 3, 2, 5, 7, 6, 1], Cost: 6
# Neighbour: [0, 1, 2, 3, 5, 7, 6, 4], Cost: 11
# Neighbour: [0, 1, 5, 2, 3, 7, 6, 4], Cost: 6
# Neighbour: [0, 1, 7, 2, 5, 3, 6, 4], Cost: 4
# Neighbour: [0, 1, 6, 2, 5, 7, 3, 4], Cost: 3
# Neighbour: [0, 1, 4, 2, 5, 7, 6, 3], Cost: 5
# Neighbour: [0, 1, 3, 5, 2, 7, 6, 4], Cost: 5
# Neighbour: [0, 1, 3, 7, 5, 2, 6, 4], Cost: 5
# Neighbour: [0, 1, 3, 6, 5, 7, 2, 4], Cost: 3
# Neighbour: [0, 1, 3, 4, 5, 7, 6, 2], Cost: 8
# Neighbour: [0, 1, 3, 2, 7, 5, 6, 4], Cost: 8
# Neighbour: [0, 1, 3, 2, 6, 7, 5, 4], Cost: 5
# Neighbour: [0, 1, 3, 2, 4, 7, 6, 5], Cost: 10
# Neighbour: [0, 1, 3, 2, 5, 6, 7, 4], Cost: 9
# Neighbour: [0, 1, 3, 2, 5, 4, 6, 7], Cost: 10
# Neighbour: [0, 1, 3, 2, 5, 7, 4, 6], Cost: 4
#
# Iteration 1
# Current State: [3, 1, 0, 2, 5, 7, 6, 4], Cost: 3
# Neighbour: [1, 3, 0, 2, 5, 7, 6, 4], Cost: 3
# Neighbour: [0, 1, 3, 2, 5, 7, 6, 4], Cost: 6
# Neighbour: [2, 1, 0, 3, 5, 7, 6, 4], Cost: 8
# Neighbour: [5, 1, 0, 2, 3, 7, 6, 4], Cost: 5
# Neighbour: [7, 1, 0, 2, 5, 3, 6, 4], Cost: 3
# Neighbour: [6, 1, 0, 2, 5, 7, 3, 4], Cost: 3
# Neighbour: [4, 1, 0, 2, 5, 7, 6, 3], Cost: 3
# Neighbour: [3, 0, 1, 2, 5, 7, 6, 4], Cost: 5
# Neighbour: [3, 2, 0, 1, 5, 7, 6, 4], Cost: 4
# Neighbour: [3, 5, 0, 2, 1, 7, 6, 4], Cost: 3
# Neighbour: [3, 7, 0, 2, 5, 1, 6, 4], Cost: 0
# Neighbour: [3, 6, 0, 2, 5, 7, 1, 4], Cost: 1
# Neighbour: [3, 4, 0, 2, 5, 7, 6, 1], Cost: 3
# Neighbour: [3, 1, 2, 0, 5, 7, 6, 4], Cost: 6
# Neighbour: [3, 1, 5, 2, 0, 7, 6, 4], Cost: 3
# Neighbour: [3, 1, 7, 2, 5, 0, 6, 4], Cost: 3
# Neighbour: [3, 1, 6, 2, 5, 7, 0, 4], Cost: 0
# Neighbour: [3, 1, 4, 2, 5, 7, 6, 0], Cost: 3
# Neighbour: [3, 1, 0, 5, 2, 7, 6, 4], Cost: 5
# Neighbour: [3, 1, 0, 7, 5, 2, 6, 4], Cost: 3
# Neighbour: [3, 1, 0, 6, 5, 7, 2, 4], Cost: 3
# Neighbour: [3, 1, 0, 4, 5, 7, 6, 2], Cost: 5
# Neighbour: [3, 1, 0, 2, 7, 5, 6, 4], Cost: 6
# Neighbour: [3, 1, 0, 2, 6, 7, 5, 4], Cost: 4
# Neighbour: [3, 1, 0, 2, 4, 7, 6, 5], Cost: 8
# Neighbour: [3, 1, 0, 2, 5, 6, 7, 4], Cost: 5
# Neighbour: [3, 1, 0, 2, 5, 4, 6, 7], Cost: 6
# Neighbour: [3, 1, 0, 2, 5, 7, 4, 6], Cost: 3
#
# Final Results
# Initial State: [0, 1, 3, 2, 5, 7, 6, 4]
# Final State (Solution): [3, 7, 0, 2, 5, 1, 6, 4]
# Final Cost (Attacking Pairs): 0
# Solution found!
